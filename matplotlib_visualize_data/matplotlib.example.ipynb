# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import seaborn

# %%
# matplotlib 한글 표시 설정
import matplotlib.font_manager as fm

# matplotlib의 글꼴 관리자에 특정 글꼴 추가
fe = fm.FontEntry(
    fname=r'font/NanumGothic.ttf',
    name='NanumGothic'
)
fm.fontManager.ttflist.insert(0, fe)

# pyplot에 matplotlib의 글꼴 관리자에 등록된 글꼴 적용
plt.rcParams.update({ 'font.family': 'NanumGothic', 'font.size': 14 })
# pyplot에서 `-`를 문자로 취급하도록 설정
plt.rcParams['axes.unicode_minus'] = False

# %%
iris = seaborn.load_dataset('iris') # 붓꽃 데이터
titanic = seaborn.load_dataset('titanic') # 타이타닉 데이터
tips = seaborn.load_dataset('tips') # 팁데이터
flights = seaborn.load_dataset('flights') # 여객기 데이터

# %% [markdown]
# ### seaborn을 활용한 1차원 분포 플롯
# seaborn 패키지에서 제공해주는 여러 가지 메서드를 활용하여 간단하게 1차원 분포 플롯을 표시할 수 있음

# %% [markdown]
# #### 1차원 실수 분포 플롯
# seaborn 패키지는 히스토그램 형식과는 다른 커널 밀도, 러그 플롯을 제공함
# `rugplot` : 데이터 위치를 x축 위에 작은 선분(rug)으로 표시 (러그 플롯)
# `kdeplot` : 히스토그램과 비슷하지만 곡선형태로 표시 (커널 플롯)

# %%
data = iris.petal_length.values
data
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %%
seaborn.rugplot(data)
plt.title('러그 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.kdeplot(data)
plt.title('커널 밀도 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 카운트 플롯
# seaborn 패키지의 `countplot()` 메서드로 각 카테고리 별 사이즈를 표시할 수 있음
# `countplot()` : 메서드는 데이터프레임만 사용 가능
# `countplot(x='컬럼명', data=데이터프레임)`

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
seaborn.countplot(x = 'embark_town', data = titanic)
plt.title('타이타닉 카운트 플롯')
# Out:
# Text(0.5, 1.0, '타이타닉 카운트 플롯')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
seaborn.countplot(x='day', data=tips)
plt.title('요일별 팁')
plt.grid(True)
plt.show()

# %% [markdown]
# ### seaborn을 활용한 다차원 데이터
# 다차원 데이터는 3가지의 경우의 수를 가질 수 있음
#
# - 모든 데이터가 실수형
# - 모든 데이터가 카테고리형
# - 데이터가 실수형과 카테고리형이 섞여 있음

# %% [markdown]
# #### 2차원 실수형 데이터
# 데이터가 2차원이면서 모두 실수이면 `jointplot()` 메서드를 사용하여 표현 할 수 있음
# `jointplot()` : 스캐터 플롯, 등고선 플롯 등을 나타낼 수 있고 양측에 히스토그램을 표현해 줌 (데이터프레임만 사용 가능)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
seaborn.jointplot(data=iris, x='sepal_length', y='sepal_width', kind='scatter')
plt.suptitle('꽃 받침의 길이와 넓이 비교 Joint plot', y=1.02)
plt.grid(True)
plt.show()

# %%
seaborn.jointplot(data=iris , x='sepal_length', y='sepal_width', kind='kde')
plt.suptitle('꽃 받침의 길이와 넓이 비교 Joint plot', y=1.02)
plt.grid(True)
plt.show()

# %% [markdown]
# #### 다차원 실수형 데이터
# 3차원 이상의데이터라면 `pairplot()` 메서드로 그리드 형태의 스캐터 플롯의 행렬을 만들어 줌, 같은 데이터가 만나는 대각선에는 각 데이터의 히스토그램을 표현

# %%
seaborn.pairplot(iris)
plt.suptitle('다차원 Pair plot', y=1.02)
plt.show()

# %% [markdown]
# 카테고리형 데이터가 포함되어 있는 경우라면 `hue` 인수에 카테고리 변수 이름을 지정함

# %%
seaborn.pairplot(iris, hue='species', markers=['o', 's', 'D'])
plt.title('다차원 Pair plot', y=1.02)
plt.show()

# %% [markdown]
# #### 2차원 카테고리 데이터
# 데이터가 2차원이면서 모두 카테고리 값이면 `heatmap()` 메서드로 히트맵을 표현할 수 있음

# %%
titanic_size = titanic.pivot_table(
    index='class', columns='sex', aggfunc='size'
)
titanic_size
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_3876\1991675946.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   titanic_size = titanic.pivot_table(
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
seaborn.heatmap(titanic_size, cmap=seaborn.light_palette('gray', as_cmap=True), annot=True, fmt='d')
plt.title('히트맵')
plt.show()

# %% [markdown]
# #### 2차원 복합 데이터
# 데이터가 2차원이면서 실수 값과 카테고리 값이 섞여 있다면 기존 플롯 외의 다른 플롯을 사용할 수 있음

# %% [markdown]
# `barplot()` : 카테고리 값에 따른 실수 값의 평균과 표준 편차를 바 형태로 표시 평균은 막대 그래프로, 편차는 에러바로 표현

# %%
seaborn.barplot(data=tips, x='day', y='total_bill')
plt.title('바 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `boxplot()` : 사분위수와 아웃라이어라는 데이터를 표현하는 방법

# %%
seaborn.boxplot(data=tips, x='day', y='total_bill')
plt.title('박스 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `violinplot()` : 세로 방향으로 커널 밀도 히스토그램을 그려줌

# %%
seaborn.violinplot(data=tips, x='day', y='total_bill')
plt.title('바이올린 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `stipplot()` : 모든 데이터를 점으로 표시해서 보여줌

# %%
seaborn.stripplot(data=tips, x='day', y='total_bill')
plt.title('스트립 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `swarmplot()` : 스트립 플롯에서 데이터가 겹치는 부분을 겹치지 않게 표현

# %%
seaborn.swarmplot(data=tips, x="day", y="total_bill")
plt.title('스웜 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# ### seaborn을 활용한 다차원 복합 데이터
# seaborn 에서 제공해주는 플롯 메서드들은 `hue` 인수로 카테고리 값을 추가로 지정 할 수 있음

# %%
seaborn.barplot(data=tips, x="day", y="total_bill", hue='sex')
plt.title('바 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.boxplot(x="day", y="total_bill", hue="sex", data=tips)
plt.title('박스 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.violinplot(x="day", y="total_bill", hue="sex", data=tips)
plt.title('바이올린 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `stipplot()`, `swarmplot()`, `violinplot()`은 `split`, `dodge`로 시각화 방법을 변경할 수 있음

# %%
seaborn.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True)
plt.title('바이올린 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.swarmplot(data=tips, x="day", y="total_bill", hue='sex',dodge=True)
plt.title('스웜 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `heatmap()`으로도 구 개의 카테고리 값에 의한 실수 값 변화를 볼 수 있음

# %%
passengers = flights.pivot(index='month', columns='year', values='passengers')
seaborn.heatmap(passengers, annot=True, fmt='d', linewidths=1)
plt.title('히트맵으로 두개의 카테고리 값 변화 비교')
plt.show()

# %% [markdown]
# ### seaborn을 활용한 catplot
# 색상과 행을 사용해서 3개 이상의 카테고리 값의 분포를 표현

# %%
data = titanic[titanic.survived.notnull()]

seaborn.catplot(data=data, x='age', y='sex', hue='survived', row='class', kind='violin', split=True, height=2, aspect=4)
plt.suptitle('캣 플롯', y=1.02)
plt.show()

# %% [markdown]
# ### seaborn을 활용한 차트 겹치기
# 시각적 효과를 높이기 위해 여러 종류의 차트를 겹쳐서 표기 가능

# %%
plt.title('박스 플롯 + 스트립 플롯')
seaborn.boxplot(x="tip", y="day", data=tips, whis=np.inf)
seaborn.stripplot(x="tip", y="day", data=tips)
plt.grid(True)
plt.show()

# %%
plt.title('바이올린 플롯 + 스웜 플롯')
seaborn.violinplot(x='day', y='tip', data=tips, inner=None)
seaborn.swarmplot(x='day', y='tip', data=tips)
plt.grid(True)
plt.show()

# %% [markdown]
# ### seaborn을 활용한 스타일 변경
# seaborn 패키지는 matplotlib에서 제공하는 기본 스타일이 아닌 특정 스타일로 변경할 수 있도록 함
# `set()` 메서드로 색상, 틱 스타일 등을 변경할 수 있음
# `set_style()` 메서드로 틱 스타일 변경할 수 있음

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for number in range(1, 7):
        plt.plot(x, np.sin(x + number * 0.5) * (7 - number) * flip)

# %%
seaborn.set_style('ticks')
sinplot()

# %%
seaborn.set_style("white")
sinplot()

# %% [markdown]
# ### pandas 패키지의 시각화 기능
# pandas 패키지의 series, dataframe 객체는 자체적으로 plot 메서드를 이용해서 시각화를 할 수 있음
# `plot()` 메서드의 `kind` 인수로 표현할 플롯을 지정할 수 있음 또는 plot 속성의 각 차트 메서드로 바로 특정 플롯으로 표현할 수 있음

# %%
df = pd.DataFrame(np.random.randn(100, 3), 
                                    index=pd.date_range('2024-03-05', periods=100), 
                                    columns=['A', 'B', 'C']).cumsum()
df
# Out:
#                     A          B         C
# 2024-03-05  -1.175517  -0.675742 -1.348031
# 2024-03-06  -0.221902  -1.732338 -3.401444
# 2024-03-07  -0.557481  -1.349687 -3.007980
# 2024-03-08  -1.783645  -0.860431 -2.922040
# 2024-03-09  -2.622519   0.800303 -3.900160
# ...               ...        ...       ...
# 2024-06-08 -24.913610  10.943244 -6.740498
# 2024-06-09 -24.730919  11.182765 -5.826216
# 2024-06-10 -26.263647   9.718245 -4.668996
# 2024-06-11 -26.140685   9.914397 -3.620144
# 2024-06-12 -25.849895  10.116210 -5.687072
#
# [100 rows x 3 columns]

# %%
df.plot()
plt.title('데이터프레임 선 그래프')
plt.xlabel('시간')
plt.ylabel('Data')
plt.show()

# %%
data = iris.sepal_length[:20]
data.plot.bar(rot=0)
plt.title('시리즈 바 차트')
plt.xlabel('Data')
plt.ylabel('꽃 받침 길이')
plt.show()

# %%
data = iris[:5]
data.plot.bar(rot=0)
plt.xlabel('Data')
plt.ylabel('Feature')
plt.ylim(0, 7)
plt.show()

# %%
data = iris.groupby(iris.species).mean()
data.columns.name = 'feature'
data.plot.bar(rot=0)
plt.title('각 종의 feature 별 평균')
plt.xlabel('평균')
plt.ylabel('종')
plt.ylim(0, 10)
plt.grid(True)
plt.show()

# %%
data = titanic.pclass.value_counts()
data.plot.pie(autopct='%.2f%%')
plt.title('선실별 승객 수 비율')
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
iris.plot.hist()
plt.title("각 Feature 값들의 빈도수 히스토그램")
plt.xlabel("Data")
plt.grid(True)
plt.show()

# %%
iris.plot.kde()
plt.title("각 Feature 값들의 빈도수에 대한 커널 분포 플롯")
plt.xlabel("Data")
plt.show()

# %%
iris.plot.box()
plt.title("각 Feature 값들의 빈도수에 대한 박스 플롯")
plt.xlabel("Feature")
plt.ylabel("Data")
plt.grid(True)
plt.show()

# %%
iris.boxplot(by='species')
plt.tight_layout()
plt.title("boxplot 메서드")
plt.show()
